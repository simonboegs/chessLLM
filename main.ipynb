# %%
import chess
import json
import os
import matplotlib.pyplot as plt
import random

# %%
filenames = os.listdir("blitz-tactics-puzzles/lichess-puzzles-v1")
ratings = []
for file in filenames:
    path = f"blitz-tactics-puzzles/lichess-puzzles-v1/{file}"
    with open(path) as f:
        data = json.load(f)
    ratings.append(data["metadata"]["rating"])

plt.hist(ratings, density=True)
# Out:
# (array([3.17703709e-04, 8.29867823e-04, 1.20318447e-03, 7.31657738e-04,
#         5.29543158e-04, 4.23974712e-04, 2.99178388e-04, 1.71978579e-04,
#         1.01759847e-04, 2.29255469e-05]),
#  array([ 767. ,  982.9, 1198.8, 1414.7, 1630.6, 1846.5, 2062.4, 2278.3,
#         2494.2, 2710.1, 2926. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ratings, 50, density=True)
# Out:
# (array([3.61816898e-04, 2.78064698e-04, 2.48298464e-04, 3.00805362e-04,
#         3.99533120e-04, 6.11594430e-04, 5.72214256e-04, 6.20838602e-04,
#         7.24927980e-04, 1.61976384e-03, 1.41269439e-03, 1.38033979e-03,
#         1.10874601e-03, 1.10819136e-03, 1.00595081e-03, 9.27745117e-04,
#         8.75053336e-04, 6.59479241e-04, 5.95694454e-04, 6.00316540e-04,
#         6.05678160e-04, 5.79794478e-04, 5.11942254e-04, 4.73301614e-04,
#         4.76999283e-04, 4.53149319e-04, 4.34660975e-04, 4.31887723e-04,
#         4.24122618e-04, 3.76052923e-04, 3.45177388e-04, 3.27798345e-04,
#         2.93779791e-04, 2.70854244e-04, 2.58282170e-04, 2.09842708e-04,
#         1.82849725e-04, 1.60848595e-04, 1.54932325e-04, 1.51419540e-04,
#         1.19249821e-04, 1.17585870e-04, 1.05568446e-04, 9.79882248e-05,
#         6.84068739e-05, 3.51278542e-05, 2.23708966e-05, 1.53453258e-05,
#         1.20174238e-05, 2.97662343e-05]),
#  array([ 767.  ,  810.18,  853.36,  896.54,  939.72,  982.9 , 1026.08,
#         1069.26, 1112.44, 1155.62, 1198.8 , 1241.98, 1285.16, 1328.34,
#         1371.52, 1414.7 , 1457.88, 1501.06, 1544.24, 1587.42, 1630.6 ,
#         1673.78, 1716.96, 1760.14, 1803.32, 1846.5 , 1889.68, 1932.86,
#         1976.04, 2019.22, 2062.4 , 2105.58, 2148.76, 2191.94, 2235.12,
#         2278.3 , 2321.48, 2364.66, 2407.84, 2451.02, 2494.2 , 2537.38,
#         2580.56, 2623.74, 2666.92, 2710.1 , 2753.28, 2796.46, 2839.64,
#         2882.82, 2926.  ]),
#  <BarContainer object of 50 artists>)

# %%
filenames = random.sample(filenames,100)

# %%
data = []

for filename in filenames:
    path = f"blitz-tactics-puzzles/lichess-puzzles-v1/{filename}"
    with open(path) as f:
        data.append(json.load(f))

data = sorted(data, key=lambda item: item["metadata"]["rating"])

with open("dataset.json","w") as f:
    f.write(json.dumps(data))

# %%
with open("blitz-tactics-puzzles/lichess-puzzles-v1/31967.json") as f:
    data = json.load(f)
    print(data)
# Out:
# {'puzzle_data': {'initial_fen': 'r1b2rk1/p4ppp/3p4/1PpNp3/2BbP1nq/P2Q4/2P2PPP/1RB2RK1 w - - 4 15', 'initial_move_san': 'Qd2', 'initial_move_uci': 'd3d2', 'puzzle_fen': 'r1b2rk1/p4ppp/3p4/1PpNp3/2BbP1nq/P7/2PQ1PPP/1RB2RK1 b - - 5 15', 'lines': {'h4h2': 'win'}}, 'metadata': {'id': 31967, 'rating': 1224, 'enabled': True, 'color': 'black', 'game_id': '1ddtvvbu', 'attempts': 26, 'vote': 0}}

# %%
initial_fen = data["puzzle_data"]["initial_fen"]
puzzle_fen = data["puzzle_data"]["puzzle_fen"]

# %%
chess.Board(fen=initial_fen).turn
# Out:
# True

# %%
chess.Board(fen=puzzle_fen).turn
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/simonboeger/Documents/cs/python/ai/chessLLM/main.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/simonboeger/Documents/cs/python/ai/chessLLM/main.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> chess.Board(fen=puzzle_fen).turn()
#
# TypeError: 'bool' object is not callable
